# %% [markdown]
# ## Results of Clustering
#
# Below are the results of running the `demo.py` script comparing results and timing of k-means clustering implementations with base Python and NumPy.

# %%
# %matplotlib inline

# %%
run demo.py --ex

# %%
run demo.py --base

# %%
run demo.py --numpy

# %%
run demo.py --count 1000

# %%
run demo.py --count 10000

# %%
run demo.py --comp
